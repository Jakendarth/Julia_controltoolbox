# %%
using ControlSystems

# %%
"""
Working with transfer functions
"""
#SISO System
G=tf([1,1+im],[1,4,6])
print(G)
# Out:
# TransferFunction{Continuous,ControlSystems.SisoRational{Complex{Int64}}}
#  s + 1 + im
# ------------
# s^2 + 4s + 6
#
# Continuous-time transfer function model

# %%
pzmap(G)

# %%
bodeplot(G)

# %%
ωgₘ, gₘ, ωϕₘ, ϕₘ =margin(G)
# Out:
# InexactError: Int64(NaN)
#
# Stacktrace:
#  [1] Int64 at .\float.jl:710 [inlined]
#  [2] convert at .\number.jl:7 [inlined]
#  [3] Complex at .\complex.jl:12 [inlined]
#  [4] Complex at .\complex.jl:35 [inlined]
#  [5] convert at .\number.jl:7 [inlined]
#  [6] setindex!(::Array{Complex{Int64},2}, ::Float64, ::Int64, ::Int64) at .\array.jl:849
#  [7] margin(::TransferFunction{Continuous,ControlSystems.SisoRational{Complex{Int64}}}, ::Array{Float64,1}; full::Bool, allMargins::Bool) at C:\Users\nkoug\.julia\packages\ControlSystems\c3tYa\src\analysis.jl:342
#  [8] margin(::TransferFunction{Continuous,ControlSystems.SisoRational{Complex{Int64}}}, ::Array{Float64,1}) at C:\Users\nkoug\.julia\packages\ControlSystems\c3tYa\src\analysis.jl:325
#  [9] margin(::TransferFunction{Continuous,ControlSystems.SisoRational{Complex{Int64}}}; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at C:\Users\nkoug\.julia\packages\ControlSystems\c3tYa\src\analysis.jl:397
# ...
